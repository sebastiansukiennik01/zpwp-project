# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./real_fake/Data_short.csv", parse_dates=['date'])

# %%
data[['subject', 'is_true']].value_counts().hist()
# Out:
# <AxesSubplot: >

# %%
pd.read_csv('real_fake\Data_short.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/admin/Desktop/zpwjp/projekt/kod/Ola.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/Users/admin/Desktop/zpwjp/projekt/kod/Ola.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> pd.read_csv('real_fake\Data_short.csv')
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %% [markdown]
# Dla poszczególnych subjectów - ile było true a ile było false
# W zależności od daty - ile kiedy było true, false

# %%
df = pd.read_csv('real_fake/Data_short.csv')
df['date'] = pd.to_datetime(df['date'])
df['month'] = df['date'].dt.to_period('M')
result = df.groupby(['month', 'is_true']).size().unstack().fillna(0)

result.plot(kind='bar', stacked=True)
plt.title('Count of Real and Fake News for Each Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.legend(['Fake', 'Real'])
plt.show()

# %%
df = df[df['date'].dt.year != 2015]
df['month'] = df['date'].dt.to_period('M')
result = df.groupby(['month', 'is_true']).size().unstack().fillna(0)

# Plot the data
result.plot(kind='bar', stacked=True)
plt.title('Count of Real and Fake News for Each Month (excluding 2015)')
plt.xlabel('Month')
plt.ylabel('Count')
plt.legend(['Fake', 'Real'])
plt.show()

# %%
subject_counts = df.groupby(['subject', 'is_true']).size().unstack(fill_value=0)

# Plot the data
subject_counts.plot(kind='bar', stacked=True)
plt.title('Count of True and False News for Each Subject')
plt.xlabel('Subject')
plt.ylabel('Count')
plt.legend(['False', 'True'])
plt.show()

# %%
data = pd.read_csv('real_fake\Fake.csv')
subject_counts = data['subject'].value_counts()
subject_counts.plot(kind='bar')
plt.title('Count of Appearances for Each Subject')
plt.xlabel('Subject')
plt.ylabel('Count')
plt.show()

# %%
data = pd.read_csv('real_fake\True.csv')
subject_counts = data['subject'].value_counts()
subject_counts.plot(kind='bar')
plt.title('Count of Appearances for Each Subject')
plt.xlabel('Subject')
plt.ylabel('Count')
plt.show()

# %%
# Out:
# month    subject
# 2015-03  left-news            2
#          politics             6
# 2015-04  Government News     79
#          left-news          121
#          politics           126
#                            ...
# 2017-12  News                48
#          US_News             18
#          left-news          125
#          politics           226
# 2018-02  politics            35
# Length: 174, dtype: int64
